# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import pilroi

import pilroi.analyze as pr

from pilroi.plotting import animate_scan

# %%
scan = pd.read_pickle('./test_data/ic19_scan.pickle')

# %% [markdown]
# Plot the anti-bragg point L=1.5.  You can clearly see the presence of two rods at this location in the scan.  The next steps I need to take include converting Pilatus image dimensions into meaningful physical quantities, e.g. convert the angular position to a reciprocal space position, and then

# %%
idx = pr.get_idx(scan, 'l', 1.5)


fig, [axim, axl] = plt.subplots(nrows=2, sharex=True, figsize=(8, 6))

axim.imshow(scan.iloc[idx]['crop'], vmax=100, vmin=1, aspect='auto')

axim.set_ylim(top=75, bottom=160)
axim.set_yticklabels([])
axim.set_yticks([])

axl.plot(scan.iloc[idx]['crop'][125, :])

axl.set_xlim(left=10, right=160)

plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="800">
